# %%
import tensorflow as tf
import tf2onnx

# %%
model = tf.keras.models.load_model('model/pickcolor.keras')

# %%
tf2onnx.convert.from_keras(model, output_path='model/pickcolor.onnx')
# Out:
# (ir_version: 8
#  producer_name: "tf2onnx"
#  producer_version: "1.14.0 8f8d49"
#  graph {
#    node {
#      input: "dense_3_input"
#      input: "sequential_1/dense_3/MatMul/ReadVariableOp:0"
#      output: "sequential_1/dense_3/MatMul:0"
#      name: "sequential_1/dense_3/MatMul"
#      op_type: "MatMul"
#    }
#    node {
#      input: "sequential_1/dense_3/MatMul:0"
#      input: "sequential_1/dense_3/BiasAdd/ReadVariableOp:0"
#      output: "sequential_1/dense_3/BiasAdd:0"
#      name: "sequential_1/dense_3/BiasAdd"
#      op_type: "Add"
#    }
#    node {
#      input: "sequential_1/dense_3/BiasAdd:0"
#      output: "sequential_1/dense_3/Relu:0"
#      name: "sequential_1/dense_3/Relu"
#      op_type: "Relu"
#    }
#    node {
#      input: "sequential_1/dense_3/Relu:0"
#      input: "sequential_1/dense_4/MatMul/ReadVariableOp:0"
#      output: "sequential_1/dense_4/MatMul:0"
#      name: "sequential_1/dense_4/MatMul"
#      op_type: "MatMul"
#    }
#    node {
# ...
