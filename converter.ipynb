# %%
import tensorflow as tf
import tf2onnx

# %%
model = tf.keras.models.load_model('model/modelColor.keras')

# %%
tf2onnx.convert.from_keras(model, output_path='model//modelColor.onnx')
# Out:
# (ir_version: 8
#  producer_name: "tf2onnx"
#  producer_version: "1.14.0 8f8d49"
#  graph {
#    node {
#      input: "dense_15_input"
#      output: "sequential_3/dense_15/Cast:0"
#      name: "sequential_3/dense_15/Cast"
#      op_type: "Cast"
#      attribute {
#        name: "to"
#        i: 1
#        type: INT
#      }
#    }
#    node {
#      input: "sequential_3/dense_15/Cast:0"
#      input: "sequential_3/dense_15/MatMul/ReadVariableOp:0"
#      output: "sequential_3/dense_15/MatMul:0"
#      name: "sequential_3/dense_15/MatMul"
#      op_type: "MatMul"
#    }
#    node {
#      input: "sequential_3/dense_15/MatMul:0"
#      input: "sequential_3/dense_15/BiasAdd/ReadVariableOp:0"
#      output: "sequential_3/dense_15/BiasAdd:0"
#      name: "sequential_3/dense_15/BiasAdd"
#      op_type: "Add"
#    }
#    node {
#      input: "sequential_3/dense_15/BiasAdd:0"
#      output: "sequential_3/dense_15/Relu:0"
#      name: "sequential_3/dense_15/Relu"
#      op_type: "Relu"
# ...
